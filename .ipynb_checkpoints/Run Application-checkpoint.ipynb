# %%
from Application1 import Application

# %%
ap = Application()
ap.root.mainloop()
# Out:
# Loaded model from disk
# ...
# 1/1 [==============================] - 0s 43ms/step

# %%
ap.str
# Out:
# ' Cs'
